# %% [markdown]
# створити заголовок 2 рівня
# текстом описати в тексті описати вставку коду на пайтоні згідно 2 завдання
#
#
#
# написати код на пайтон який буде читати рядки з файла

# %% [markdown]
# написати клас з конструктором в якій передається один аргумент яким повинен бути список і створити проперті яка буде повератити довжину цього списку
